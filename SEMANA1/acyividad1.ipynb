# %%
nombre_de_usuario = input("Ingrese su nombre: ")
saludo_a_usuario = print("hola, ", nombre_de_usuario)
horas_dedicadas_a_fortnite = float(input("ingresa el numero de horas que dedicas a fortnite: "))
horas_dedicadas_a_instagram = float(input("ingresa el numeron de horas que dedicas a instagram: "))
horas_dedicadas_a_tiktok = float(input("ingresa el numero de horas que dedicas a tiktok: "))
horas_dedicadas_a_youtube = float(input("ingresa el numero de horas que dedicas a youtube: "))
horas_dedicadas_a_facebook = float(input("ingresa el numero de horas que dedicas a facebook: "))
tiempo_total = (horas_dedicadas_a_fortnite + horas_dedicadas_a_instagram + horas_dedicadas_a_tiktok + horas_dedicadas_a_youtube + horas_dedicadas_a_facebook)
porcentaje_de_tiempo_dedicado_a_redes_sociales_y_videojuegos = (tiempo_total / 24) * 100
print("el tiempo total que dedicas a las redes sociales y videojuegos es: ", tiempo_total, "horas")
print("el porcentaje de tiempo que dedicas a las redes sociales y videojuegos es: ", porcentaje_de_tiempo_dedicado_a_redes_sociales_y_videojuegos, "%")
print(f"usuario: {nombre_de_usuario}")
print(f"tiempo total dedicado a redes sociales y videojuegos: {tiempo_total} horas")
print(f"porcentaje de tiempo dedicado a redes sociales y videojuegos: {porcentaje_de_tiempo_dedicado_a_redes_sociales_y_videojuegos}%")
# Out:
# hola,  Luis
# el tiempo total que dedicas a las redes sociales y videojuegos es:  12.5 horas
# el porcentaje de tiempo que dedicas a las redes sociales y videojuegos es:  52.083333333333336 %
# usuario: Luis
# tiempo total dedicado a redes sociales y videojuegos: 12.5 horas
# porcentaje de tiempo dedicado a redes sociales y videojuegos: 52.083333333333336%
