# %%
edad = 46
if edad >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres mayor de edad

# %%
calificacion = 52

if calificacion >= 90:
    print("A")
elif calificacion >= 80:
    print("B")
elif calificacion >= 70:
    print("C")
elif calificacion >= 60:
    print("D")
else:
    print("Estas reprobado")
# Out:
# Estas reprobado

# %%
PL1 = True
PL2 = False

print(PL1 or PL2)
# Out:
# True

# %%
edad = 55
tipo = "Adulto_mayor"

es_mayor = edad >= 18
print(es_mayor)
aplica_descuento = (edad >= 60) and (tipo == "Adulto_mayor")
print(aplica_descuento)
# Out:
# True
# False

# %%
edad = int(input("Ingresa tu edad"))

if not (edad > 0 ):
    print("Aguanta, no hay edades menores de cero")
else:
    print("Ahora si vamos a trabajar con edades reales")
# Out:
# Aguanta, no hay edades menores de cero

# %%
numero = int(input("Ingrese un numero entero"))
if(numero % 2 == 0):
    print("Es numero par")
else:
    print("es numero inpar")
# Out:
# es numero inpar

# %%
edad = int(input("Ingrese su edad"))

if(edad <= 3):
    print("Eres un bebe ")
elif(edad <= 12):
    print("Eres un niño")
elif(edad <= 17):
    print("Eres un adolescente")
elif(edad >= 18):
    print("eres mayor de edad")
# Out:
# Eres un adolescente
